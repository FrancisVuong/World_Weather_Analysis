# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['san patricio', 'beringovskiy', 'san agustin', 'port hardy', 'paratinga', 'bethel', 'avera', 'olinda', 'santa rosa', 'khatanga'] Generate 768

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = list()
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if i % 50 == 0 and i != 0 :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        js = requests.get(url).json()
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']

        # raining info
        try:
            js['weather'][0]['main'] == 'Rain'
            city_rain = js['rain']['3h']
        except:
            city_rain = 0.000

        # snowing info
        try:
            js['weather'][0]['main'] == 'Snow'
            city_snow = js['snow']['3h']
        except:
            city_snow = 0    

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description,
                        'Rain inches (last 3 hrs)':city_rain,'Snow inches (last 3 hrs)':city_snow})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | beringovskiy
# Processing Record 3 of Set 1 | san agustin
# Processing Record 4 of Set 1 | port hardy
# Processing Record 5 of Set 1 | paratinga
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | avera
# Processing Record 8 of Set 1 | olinda
# Processing Record 9 of Set 1 | santa rosa
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | moranbah
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | mount gambier
# Processing Record 20 of Set 1 | waipawa
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | roald
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | te anau
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | aripuana
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | weyburn
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | banda aceh
# Processing Record 37 of Set 1 | pingliang
# Processing Record 38 of Set 1 | boyolangu
# Processing Record 39 of Set 1 | bielsko-biala
# Processing Record 40 of Set 1 | payson
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | trairi
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | pisco
# Processing Record 47 of Set 1 | santo domingo
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | alta floresta
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | pacific grove
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | geraldton
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | moyale
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | arinos
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | esperance
# Processing Record 18 of Set 2 | cambridge
# Processing Record 19 of Set 2 | alice springs
# Processing Record 20 of Set 2 | poltavka
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | pangnirtung
# Processing Record 23 of Set 2 | mumbwa
# Processing Record 24 of Set 2 | nchelenge
# Processing Record 25 of Set 2 | saldanha
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | makakilo city
# Processing Record 28 of Set 2 | volosovo
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | miri
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | makhachkala
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | mudon
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | dolores
# Processing Record 37 of Set 2 | mayo
# Processing Record 38 of Set 2 | mamallapuram
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | russell
# Processing Record 42 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | bandarbeyla
# Processing Record 44 of Set 2 | la peca
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | xiaoweizhai
# Processing Record 47 of Set 2 | benguela
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | oyonnax
# Processing Record 50 of Set 2 | praia
# Processing Record 1 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 3 | chumikan
# Processing Record 3 of Set 3 | kavaratti
# Processing Record 4 of Set 3 | princeton
# Processing Record 5 of Set 3 | garowe
# Processing Record 6 of Set 3 | bahadurganj
# Processing Record 7 of Set 3 | ngunguru
# Processing Record 8 of Set 3 | anaco
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | aswan
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | elizabethtown
# Processing Record 13 of Set 3 | saint-georges
# Processing Record 14 of Set 3 | midland
# Processing Record 15 of Set 3 | haines junction
# Processing Record 16 of Set 3 | dhidhdhoo
# Processing Record 17 of Set 3 | rio pardo
# Processing Record 18 of Set 3 | puerto madryn
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | srednekolymsk
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | ushuaia
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | kodiak
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | la ronge
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | quatre cocos
# Processing Record 30 of Set 3 | ketchikan
# Processing Record 31 of Set 3 | belaya gora
# Processing Record 32 of Set 3 | bagua grande
# Processing Record 33 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 3 | izmit
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | walvis bay
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | butaritari
# Processing Record 39 of Set 3 | san carlos del zulia
# Processing Record 40 of Set 3 | tongliao
# Processing Record 41 of Set 3 | okitipupa
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | new amsterdam
# Processing Record 44 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 3 | busselton
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | shu
# Processing Record 48 of Set 3 | channel-port aux basques
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | san quintin
# Processing Record 1 of Set 4 | san pedro
# Processing Record 2 of Set 4 | henties bay
# Processing Record 3 of Set 4 | iqaluit
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | honningsvag
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | chaplygin
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 4 | kushmurun
# Processing Record 14 of Set 4 | pimentel
# Processing Record 15 of Set 4 | mackenzie
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | haicheng
# Processing Record 18 of Set 4 | pryazha
# Processing Record 19 of Set 4 | khorramshahr
# Processing Record 20 of Set 4 | lorengau
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | hilo
# Processing Record 23 of Set 4 | maragogi
# Processing Record 24 of Set 4 | hwange
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | saint paul
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | poum
# Processing Record 29 of Set 4 | baijiantan
# Processing Record 30 of Set 4 | kampen
# Processing Record 31 of Set 4 | manta
# Processing Record 32 of Set 4 | sencha
# Processing Record 33 of Set 4 | hauterive
# Processing Record 34 of Set 4 | sayyan
# Processing Record 35 of Set 4 | tianpeng
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 4 | okha
# Processing Record 39 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | imeni poliny osipenko
# Processing Record 42 of Set 4 | stephenville
# Processing Record 43 of Set 4 | launceston
# Processing Record 44 of Set 4 | chiplun
# Processing Record 45 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 4 | dattapur
# Processing Record 47 of Set 4 | kidal
# Processing Record 48 of Set 4 | port macquarie
# Processing Record 49 of Set 4 | husavik
# Processing Record 50 of Set 4 | bahia blanca
# Processing Record 1 of Set 5 | naze
# Processing Record 2 of Set 5 | juegang
# Processing Record 3 of Set 5 | khani
# Processing Record 4 of Set 5 | plettenberg bay
# Processing Record 5 of Set 5 | el rosario
# Processing Record 6 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | pinawa
# Processing Record 9 of Set 5 | atambua
# Processing Record 10 of Set 5 | southbury
# Processing Record 11 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 5 | vaitape
# Processing Record 13 of Set 5 | chokurdakh
# Processing Record 14 of Set 5 | saint-denis
# Processing Record 15 of Set 5 | moron
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | bend
# Processing Record 18 of Set 5 | sidney
# Processing Record 19 of Set 5 | kalevala
# Processing Record 20 of Set 5 | formosa
# Processing Record 21 of Set 5 | sigli
# Processing Record 22 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 5 | srivardhan
# Processing Record 24 of Set 5 | mingoyo
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | roma
# Processing Record 27 of Set 5 | salta
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | ossora
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | yei
# Processing Record 33 of Set 5 | tarumovka
# Processing Record 34 of Set 5 | rorvik
# Processing Record 35 of Set 5 | belmonte
# Processing Record 36 of Set 5 | orange cove
# Processing Record 37 of Set 5 | mareeba
# Processing Record 38 of Set 5 | naryan-mar
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | linjiang
# Processing Record 41 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 5 | muisne
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | baruun-urt
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | sibut
# Processing Record 47 of Set 5 | vila do maio
# Processing Record 48 of Set 5 | mocuba
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | archdale
# Processing Record 1 of Set 6 | mfou
# Processing Record 2 of Set 6 | karia
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | rawson
# Processing Record 5 of Set 6 | tyukhtet
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | sidi ali
# Processing Record 8 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 6 | voyvozh
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | betafo
# Processing Record 12 of Set 6 | strezhevoy
# Processing Record 13 of Set 6 | qaqortoq
# Processing Record 14 of Set 6 | christchurch
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | almazar
# Processing Record 17 of Set 6 | kailua
# Processing Record 18 of Set 6 | grants
# Processing Record 19 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | cacoal
# Processing Record 22 of Set 6 | anadyr
# Processing Record 23 of Set 6 | araouane
# Processing Record 24 of Set 6 | aban
# Processing Record 25 of Set 6 | billings
# Processing Record 26 of Set 6 | parauna
# Processing Record 27 of Set 6 | kutum
# Processing Record 28 of Set 6 | padang
# Processing Record 29 of Set 6 | goroka
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | kapoeta
# Processing Record 32 of Set 6 | paamiut
# Processing Record 33 of Set 6 | laguna
# Processing Record 34 of Set 6 | avarua
# Processing Record 35 of Set 6 | tefe
# Processing Record 36 of Set 6 | clyde river
# Processing Record 37 of Set 6 | madang
# Processing Record 38 of Set 6 | tasiilaq
# Processing Record 39 of Set 6 | vao
# Processing Record 40 of Set 6 | itarema
# Processing Record 41 of Set 6 | santiago de cao
# Processing Record 42 of Set 6 | lavrentiya
# Processing Record 43 of Set 6 | akyab
# Processing Record 44 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | hualmay
# Processing Record 47 of Set 6 | havelock
# Processing Record 48 of Set 6 | saint-junien
# Processing Record 49 of Set 6 | jacareacanga
# Processing Record 50 of Set 6 | nishihara
# Processing Record 1 of Set 7 | lagoa
# Processing Record 2 of Set 7 | darhan
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 7 | portpatrick
# City not found. Skipping...
# Processing Record 6 of Set 7 | qui nhon
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | bilma
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | sinazongwe
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | xining
# Processing Record 13 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 14 of Set 7 | zamora
# Processing Record 15 of Set 7 | imbituba
# Processing Record 16 of Set 7 | kondopoga
# Processing Record 17 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 7 | san cristobal
# Processing Record 20 of Set 7 | thinadhoo
# Processing Record 21 of Set 7 | lebu
# Processing Record 22 of Set 7 | tezu
# Processing Record 23 of Set 7 | bintulu
# Processing Record 24 of Set 7 | marrakesh
# Processing Record 25 of Set 7 | pyaozerskiy
# Processing Record 26 of Set 7 | uvarovo
# Processing Record 27 of Set 7 | upernavik
# Processing Record 28 of Set 7 | zykovo
# Processing Record 29 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 30 of Set 7 | sasayama
# Processing Record 31 of Set 7 | nawa
# Processing Record 32 of Set 7 | chara
# Processing Record 33 of Set 7 | bezhetsk
# Processing Record 34 of Set 7 | tevriz
# Processing Record 35 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 7 | talnakh
# Processing Record 37 of Set 7 | ranong
# Processing Record 38 of Set 7 | pecos
# Processing Record 39 of Set 7 | gamba
# Processing Record 40 of Set 7 | college
# Processing Record 41 of Set 7 | tomatlan
# Processing Record 42 of Set 7 | trogir
# Processing Record 43 of Set 7 | yakeshi
# Processing Record 44 of Set 7 | apatity
# Processing Record 45 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 7 | ekhabi
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | amahai
# Processing Record 49 of Set 7 | bereda
# Processing Record 50 of Set 7 | karlskrona
# Processing Record 1 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 8 | pekalongan
# Processing Record 3 of Set 8 | betare oya
# Processing Record 4 of Set 8 | sorland
# Processing Record 5 of Set 8 | tukrah
# Processing Record 6 of Set 8 | bathsheba
# Processing Record 7 of Set 8 | igarka
# Processing Record 8 of Set 8 | cherskiy
# Processing Record 9 of Set 8 | villazon
# Processing Record 10 of Set 8 | eureka
# Processing Record 11 of Set 8 | alexandria
# Processing Record 12 of Set 8 | ruidoso
# Processing Record 13 of Set 8 | saquarema
# Processing Record 14 of Set 8 | coxim
# Processing Record 15 of Set 8 | port huron
# Processing Record 16 of Set 8 | nagato
# Processing Record 17 of Set 8 | emirdag
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | markivka
# Processing Record 20 of Set 8 | udachnyy
# Processing Record 21 of Set 8 | jamame
# Processing Record 22 of Set 8 | urozhaynoye
# Processing Record 23 of Set 8 | tazovskiy
# Processing Record 24 of Set 8 | jiaojiang
# Processing Record 25 of Set 8 | yuyao
# Processing Record 26 of Set 8 | dunhua
# Processing Record 27 of Set 8 | tambo
# Processing Record 28 of Set 8 | lumut
# Processing Record 29 of Set 8 | shingu
# Processing Record 30 of Set 8 | qurunbaliyah
# City not found. Skipping...
# Processing Record 31 of Set 8 | maniitsoq
# Processing Record 32 of Set 8 | hondo
# Processing Record 33 of Set 8 | lisakovsk
# Processing Record 34 of Set 8 | vysokogornyy
# Processing Record 35 of Set 8 | fortuna
# Processing Record 36 of Set 8 | bicaz
# Processing Record 37 of Set 8 | nizwa
# Processing Record 38 of Set 8 | hasaki
# Processing Record 39 of Set 8 | pechora
# Processing Record 40 of Set 8 | muros
# Processing Record 41 of Set 8 | barao de melgaco
# Processing Record 42 of Set 8 | goderich
# Processing Record 43 of Set 8 | marawi
# Processing Record 44 of Set 8 | burnie
# Processing Record 45 of Set 8 | port blair
# Processing Record 46 of Set 8 | defiance
# Processing Record 47 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 48 of Set 8 | faenza
# Processing Record 49 of Set 8 | nemuro
# Processing Record 50 of Set 8 | brigantine
# Processing Record 1 of Set 9 | yertsevo
# Processing Record 2 of Set 9 | zambezi
# Processing Record 3 of Set 9 | rosarito
# Processing Record 4 of Set 9 | namibe
# Processing Record 5 of Set 9 | ingham
# Processing Record 6 of Set 9 | camana
# Processing Record 7 of Set 9 | sabang
# Processing Record 8 of Set 9 | culebra
# Processing Record 9 of Set 9 | omsukchan
# Processing Record 10 of Set 9 | sawakin
# Processing Record 11 of Set 9 | ayan
# Processing Record 12 of Set 9 | fort nelson
# Processing Record 13 of Set 9 | yining
# Processing Record 14 of Set 9 | kirakira
# Processing Record 15 of Set 9 | shirokiy
# Processing Record 16 of Set 9 | cabedelo
# Processing Record 17 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 9 | nioro
# Processing Record 19 of Set 9 | acarau
# Processing Record 20 of Set 9 | ola
# Processing Record 21 of Set 9 | port-gentil
# Processing Record 22 of Set 9 | rio grande
# Processing Record 23 of Set 9 | severo-yeniseyskiy
# Processing Record 24 of Set 9 | taoudenni
# Processing Record 25 of Set 9 | nanortalik
# Processing Record 26 of Set 9 | basco
# Processing Record 27 of Set 9 | sitka
# Processing Record 28 of Set 9 | tianmen
# Processing Record 29 of Set 9 | lieksa
# Processing Record 30 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 31 of Set 9 | vanimo
# Processing Record 32 of Set 9 | ambon
# Processing Record 33 of Set 9 | bud
# Processing Record 34 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 9 | lang son
# Processing Record 36 of Set 9 | vieques
# Processing Record 37 of Set 9 | ponta delgada
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 9 | kushima
# Processing Record 41 of Set 9 | piranshahr
# Processing Record 42 of Set 9 | maldonado
# Processing Record 43 of Set 9 | boa vista
# Processing Record 44 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 9 | kothi
# Processing Record 46 of Set 9 | nijar
# Processing Record 47 of Set 9 | seversk
# Processing Record 48 of Set 9 | lakselv
# Processing Record 49 of Set 9 | duiwelskloof
# Processing Record 50 of Set 9 | kenora
# Processing Record 1 of Set 10 | trud
# Processing Record 2 of Set 10 | oksfjord
# Processing Record 3 of Set 10 | kununurra
# Processing Record 4 of Set 10 | saint-francois
# Processing Record 5 of Set 10 | hun
# Processing Record 6 of Set 10 | baykit
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | platteville
# Processing Record 9 of Set 10 | conde
# Processing Record 10 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 11 of Set 10 | olafsvik
# Processing Record 12 of Set 10 | armidale
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | vostok
# Processing Record 15 of Set 10 | vavoua
# Processing Record 16 of Set 10 | vryburg
# Processing Record 17 of Set 10 | along
# Processing Record 18 of Set 10 | paragominas
# Processing Record 19 of Set 10 | san juan
# Processing Record 20 of Set 10 | maryborough
# Processing Record 21 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 10 | lysva
# Processing Record 23 of Set 10 | broken hill
# Processing Record 24 of Set 10 | hasilpur
# Processing Record 25 of Set 10 | simpang
# Processing Record 26 of Set 10 | melaka
# Processing Record 27 of Set 10 | samfya
# Processing Record 28 of Set 10 | marzuq
# Processing Record 29 of Set 10 | zemio
# Processing Record 30 of Set 10 | magadan
# Processing Record 31 of Set 10 | urumqi
# Processing Record 32 of Set 10 | gisborne
# Processing Record 33 of Set 10 | awbari
# Processing Record 34 of Set 10 | sisimiut
# Processing Record 35 of Set 10 | tornio
# Processing Record 36 of Set 10 | bontang
# Processing Record 37 of Set 10 | margate
# Processing Record 38 of Set 10 | kangaatsiaq
# Processing Record 39 of Set 10 | gogrial
# Processing Record 40 of Set 10 | andros town
# Processing Record 41 of Set 10 | beloha
# Processing Record 42 of Set 10 | faanui
# Processing Record 43 of Set 10 | paraiba do sul
# Processing Record 44 of Set 10 | brae
# Processing Record 45 of Set 10 | abu samrah
# Processing Record 46 of Set 10 | dzerzhinsk
# Processing Record 47 of Set 10 | ust-nera
# Processing Record 48 of Set 10 | sistranda
# Processing Record 49 of Set 10 | kampong thum
# Processing Record 50 of Set 10 | chapais
# Processing Record 1 of Set 11 | hofn
# Processing Record 2 of Set 11 | notre-dame-de-gravenchon
# Processing Record 3 of Set 11 | tselinnoye
# Processing Record 4 of Set 11 | biak
# Processing Record 5 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 11 | la rioja
# Processing Record 7 of Set 11 | maxixe
# Processing Record 8 of Set 11 | fort-shevchenko
# Processing Record 9 of Set 11 | tombouctou
# Processing Record 10 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 11 | roberval
# Processing Record 12 of Set 11 | carora
# Processing Record 13 of Set 11 | seoul
# Processing Record 14 of Set 11 | santana do mundau
# Processing Record 15 of Set 11 | general roca
# Processing Record 16 of Set 11 | aklavik
# Processing Record 17 of Set 11 | belvedere marittimo
# Processing Record 18 of Set 11 | celendin
# Processing Record 19 of Set 11 | santarem
# Processing Record 20 of Set 11 | celestun
# Processing Record 21 of Set 11 | isangel
# Processing Record 22 of Set 11 | rantoul
# Processing Record 23 of Set 11 | atasu
# Processing Record 24 of Set 11 | batagay
# Processing Record 25 of Set 11 | paita
# Processing Record 26 of Set 11 | khash
# Processing Record 27 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 11 | balkanabat
# Processing Record 29 of Set 11 | knysna
# Processing Record 30 of Set 11 | severo-kurilsk
# Processing Record 31 of Set 11 | grand gaube
# Processing Record 32 of Set 11 | kaduqli
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 11 | daru
# Processing Record 36 of Set 11 | lasa
# Processing Record 37 of Set 11 | tottori
# Processing Record 38 of Set 11 | cap malheureux
# Processing Record 39 of Set 11 | westport
# Processing Record 40 of Set 11 | tanout
# Processing Record 41 of Set 11 | the valley
# Processing Record 42 of Set 11 | forrest city
# Processing Record 43 of Set 11 | cassilandia
# Processing Record 44 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 11 | safaqis
# City not found. Skipping...
# Processing Record 46 of Set 11 | bejar
# Processing Record 47 of Set 11 | portree
# Processing Record 48 of Set 11 | kleive
# Processing Record 49 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 11 | trinidad
# Processing Record 1 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 2 of Set 12 | takoradi
# Processing Record 3 of Set 12 | portland
# Processing Record 4 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 12 | nizhnevartovsk
# Processing Record 6 of Set 12 | sao felix do xingu
# Processing Record 7 of Set 12 | sunnyside
# Processing Record 8 of Set 12 | vila
# Processing Record 9 of Set 12 | unye
# City not found. Skipping...
# Processing Record 10 of Set 12 | sakakah
# Processing Record 11 of Set 12 | mahebourg
# Processing Record 12 of Set 12 | san ramon
# Processing Record 13 of Set 12 | novikovo
# Processing Record 14 of Set 12 | tautira
# Processing Record 15 of Set 12 | koungou
# Processing Record 16 of Set 12 | canala
# Processing Record 17 of Set 12 | ancud
# Processing Record 18 of Set 12 | ishigaki
# Processing Record 19 of Set 12 | cervo
# Processing Record 20 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 12 | athabasca
# Processing Record 22 of Set 12 | asau
# Processing Record 23 of Set 12 | noumea
# Processing Record 24 of Set 12 | wesselsbron
# Processing Record 25 of Set 12 | solnechnyy
# Processing Record 26 of Set 12 | korla
# Processing Record 27 of Set 12 | valle de allende
# Processing Record 28 of Set 12 | camapua
# Processing Record 29 of Set 12 | lasem
# Processing Record 30 of Set 12 | dakar
# Processing Record 31 of Set 12 | ipora
# Processing Record 32 of Set 12 | van
# Processing Record 33 of Set 12 | starkville
# Processing Record 34 of Set 12 | beidao
# Processing Record 35 of Set 12 | leshukonskoye
# Processing Record 36 of Set 12 | eirunepe
# Processing Record 37 of Set 12 | porangatu
# Processing Record 38 of Set 12 | yacopi
# Processing Record 39 of Set 12 | auki
# Processing Record 40 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 12 | port hope
# Processing Record 42 of Set 12 | tilichiki
# Processing Record 43 of Set 12 | dubbo
# Processing Record 44 of Set 12 | los llanos de aridane
# Processing Record 45 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 12 | campobasso
# Processing Record 47 of Set 12 | torrington
# Processing Record 48 of Set 12 | hay river
# Processing Record 49 of Set 12 | springfield
# Processing Record 50 of Set 12 | lubango
# Processing Record 1 of Set 13 | kabo
# Processing Record 2 of Set 13 | lata
# Processing Record 3 of Set 13 | staraya poltavka
# Processing Record 4 of Set 13 | kutahya
# Processing Record 5 of Set 13 | dolinsk
# Processing Record 6 of Set 13 | calvinia
# Processing Record 7 of Set 13 | gushikawa
# Processing Record 8 of Set 13 | gombong
# Processing Record 9 of Set 13 | ouahigouya
# Processing Record 10 of Set 13 | puro
# Processing Record 11 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 13 | weymouth
# Processing Record 13 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 13 | ambulu
# Processing Record 15 of Set 13 | maanshan
# Processing Record 16 of Set 13 | seddon
# Processing Record 17 of Set 13 | sao francisco de assis
# Processing Record 18 of Set 13 | yeppoon
# Processing Record 19 of Set 13 | baghdad
# Processing Record 20 of Set 13 | mantua
# Processing Record 21 of Set 13 | kaka
# Processing Record 22 of Set 13 | vila velha
# Processing Record 23 of Set 13 | evansville
# Processing Record 24 of Set 13 | el olivar
# Processing Record 25 of Set 13 | coquimbo
# Processing Record 26 of Set 13 | chinchani
# Processing Record 27 of Set 13 | manati
# Processing Record 28 of Set 13 | progreso
# Processing Record 29 of Set 13 | arvika
# Processing Record 30 of Set 13 | yar-sale
# Processing Record 31 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 32 of Set 13 | quesnel
# Processing Record 33 of Set 13 | kupang
# Processing Record 34 of Set 13 | cayambe
# Processing Record 35 of Set 13 | kosikha
# Processing Record 36 of Set 13 | khimarros
# City not found. Skipping...
# Processing Record 37 of Set 13 | asfi
# Processing Record 38 of Set 13 | beaverlodge
# Processing Record 39 of Set 13 | abu kamal
# Processing Record 40 of Set 13 | benjamin constant
# Processing Record 41 of Set 13 | nagykoros
# Processing Record 42 of Set 13 | sembe
# Processing Record 43 of Set 13 | caraquet
# Processing Record 44 of Set 13 | ballina
# Processing Record 45 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 13 | horsham
# Processing Record 48 of Set 13 | katobu
# Processing Record 49 of Set 13 | goundam
# Processing Record 50 of Set 13 | libertador general san martin
# Processing Record 1 of Set 14 | veraval
# Processing Record 2 of Set 14 | iwanai
# Processing Record 3 of Set 14 | valparaiso
# Processing Record 4 of Set 14 | kokopo
# Processing Record 5 of Set 14 | timbiqui
# Processing Record 6 of Set 14 | ust-uda
# Processing Record 7 of Set 14 | vilyuysk
# Processing Record 8 of Set 14 | erzin
# Processing Record 9 of Set 14 | jiutai
# Processing Record 10 of Set 14 | salinas
# Processing Record 11 of Set 14 | grand-santi
# Processing Record 12 of Set 14 | chiaravalle
# Processing Record 13 of Set 14 | terra santa
# Processing Record 14 of Set 14 | linxia
# Processing Record 15 of Set 14 | los pozos
# Processing Record 16 of Set 14 | komsomolskiy
# Processing Record 17 of Set 14 | yaan
# Processing Record 18 of Set 14 | kokstad
# Processing Record 19 of Set 14 | shizunai
# Processing Record 20 of Set 14 | santiago del estero
# Processing Record 21 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 14 | ibotirama
# Processing Record 23 of Set 14 | zyryanka
# Processing Record 24 of Set 14 | mezen
# Processing Record 25 of Set 14 | florianopolis
# Processing Record 26 of Set 14 | robertsport
# Processing Record 27 of Set 14 | envira
# Processing Record 28 of Set 14 | guaimaro
# Processing Record 29 of Set 14 | dengzhou
# Processing Record 30 of Set 14 | nerviano
# Processing Record 31 of Set 14 | torrevieja
# Processing Record 32 of Set 14 | vestmanna
# Processing Record 33 of Set 14 | vizinga
# Processing Record 34 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 14 | muncar
# Processing Record 36 of Set 14 | hobyo
# Processing Record 37 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 14 | chernyshevskiy
# Processing Record 39 of Set 14 | syracuse
# Processing Record 40 of Set 14 | zeya
# Processing Record 41 of Set 14 | ladushkin
# Processing Record 42 of Set 14 | malanje
# Processing Record 43 of Set 14 | laredo
# Processing Record 44 of Set 14 | nantucket
# Processing Record 45 of Set 14 | yangambi
# Processing Record 46 of Set 14 | drovyanaya
# Processing Record 47 of Set 14 | cerrik
# Processing Record 48 of Set 14 | tiznit
# Processing Record 49 of Set 14 | samtredia
# Processing Record 50 of Set 14 | waddan
# Processing Record 1 of Set 15 | xuzhou
# Processing Record 2 of Set 15 | belomorsk
# Processing Record 3 of Set 15 | dimitrovgrad
# Processing Record 4 of Set 15 | arusha
# Processing Record 5 of Set 15 | tarabuco
# Processing Record 6 of Set 15 | broome
# Processing Record 7 of Set 15 | gladstone
# Processing Record 8 of Set 15 | alugan
# Processing Record 9 of Set 15 | azuaga
# Processing Record 10 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 15 | emet
# Processing Record 12 of Set 15 | nortelandia
# Processing Record 13 of Set 15 | mitsamiouli
# Processing Record 14 of Set 15 | gobabis
# Processing Record 15 of Set 15 | ocampo
# Processing Record 16 of Set 15 | floro
# Processing Record 17 of Set 15 | moose factory
# Processing Record 18 of Set 15 | peniche
# Processing Record 19 of Set 15 | ambanja
# Processing Record 20 of Set 15 | dabat
# Processing Record 21 of Set 15 | kaitangata
# Processing Record 22 of Set 15 | bijawar
# Processing Record 23 of Set 15 | pangkalanbuun
# Processing Record 24 of Set 15 | potrerillos abajo
# Processing Record 25 of Set 15 | krechevitsy
# Processing Record 26 of Set 15 | saint anthony
# Processing Record 27 of Set 15 | filingue
# Processing Record 28 of Set 15 | kemijarvi
# Processing Record 29 of Set 15 | maarianhamina
# Processing Record 30 of Set 15 | chiredzi
# Processing Record 31 of Set 15 | woodstock
# Processing Record 32 of Set 15 | khandyga
# Processing Record 33 of Set 15 | abaza
# Processing Record 34 of Set 15 | bose
# Processing Record 35 of Set 15 | baikunthpur
# Processing Record 36 of Set 15 | manzanillo
# Processing Record 37 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 15 | salym
# Processing Record 39 of Set 15 | dawei
# Processing Record 40 of Set 15 | anage
# Processing Record 41 of Set 15 | malindi
# Processing Record 42 of Set 15 | hagere hiywet
# Processing Record 43 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 44 of Set 15 | kazachinskoye
# Processing Record 45 of Set 15 | meulaboh
# Processing Record 46 of Set 15 | dunedin
# Processing Record 47 of Set 15 | matamoros
# Processing Record 48 of Set 15 | labuhan
# Processing Record 49 of Set 15 | kikwit
# Processing Record 50 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 16 | homa bay
# Processing Record 2 of Set 16 | rebrikha
# Processing Record 3 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 16 | porto novo
# Processing Record 5 of Set 16 | alyangula
# Processing Record 6 of Set 16 | qasigiannguit
# Processing Record 7 of Set 16 | sobolevo
# Processing Record 8 of Set 16 | kieta
# Processing Record 9 of Set 16 | meadow lake
# Processing Record 10 of Set 16 | itaberai
# Processing Record 11 of Set 16 | nichinan
# Processing Record 12 of Set 16 | tanabe
# Processing Record 13 of Set 16 | oktyabrskiy
# Processing Record 14 of Set 16 | sheltozero
# Processing Record 15 of Set 16 | necochea
# Processing Record 16 of Set 16 | camopi
# Processing Record 17 of Set 16 | ust-koksa
# Processing Record 18 of Set 16 | codrington
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 700

# %%
# Confirming that new dataframe works.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  san patricio      US  2021-12-12 12:16:53  28.0170  -97.5169     51.84
# 1  beringovskiy      RU  2021-12-12 12:16:54  63.0500  179.3167    -24.43
# 2   san agustin      MX  2021-12-12 12:16:54  20.5333 -103.4667     54.32
# 3    port hardy      CA  2021-12-12 12:16:54  50.6996 -127.4199     37.76
# 4     paratinga      BR  2021-12-12 12:16:55 -12.6906  -43.1842     75.81
# 5        bethel      US  2021-12-12 12:16:55  41.3712  -73.4140     43.38
# 6         avera      US  2021-12-12 12:16:55  33.1940  -82.5271     51.67
# 7        olinda      BR  2021-12-12 12:13:54  -8.0089  -34.8553     85.73
# 8    santa rosa      PH  2021-12-12 12:16:56  14.3122  121.1114     81.10
# 9      khatanga      RU  2021-12-12 12:16:56  71.9667  102.5000    -50.01
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        47         100        6.24     overcast clouds
# 1        98          44        8.48    scattered clouds
# 2        80          40        0.00    scattered clouds
# 3        84         100        6.64          light rain
# 4        83          99        5.06     overcast clouds
# 5        54           1        4.00           clear sky
# 6        71         100        8.10     overcast clouds
# 7        62          40        9.22    scattered clouds
# 8        80          83       13.00       broken clouds
# 9       100          58        1.97       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                       0.0                         0
# 1                       0.0                         0
# 2                       0.0                         0
# 3                       0.0                         0
# 4                       0.0                         0
# 5                       0.0                         0
# 6                       0.0                         0
# 7                       0.0                         0
# 8                       0.0                         0
# 9                       0.0                         0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
